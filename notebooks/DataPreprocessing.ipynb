# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dataset_raw.csv")

# %%
df.head()
# Out:
#          Date  Year  Month  Month_Number MonthName Quarter FinancialYear  \
# 0  2013-01-02  2013      1             1   January      Q1       FY12-13
# 1  2013-01-03  2013      1             1   January      Q1       FY12-13
# 2  2013-01-04  2013      1             1   January      Q1       FY12-13
# 3  2013-01-05  2013      1             1   January      Q1       FY12-13
# 4  2013-01-07  2013      1             1   January      Q1       FY12-13
#
#    Gold_Price_USD_per_oz  Gold_Open_USD  Gold_High_USD  ...  \
# 0                 1670.6         1665.2         1683.0  ...
# 1                 1572.3         1578.5         1586.9  ...
# 2                 1600.9         1598.1         1601.6  ...
# 3                 1446.2         1475.6         1477.4  ...
# 4                 1255.7         1232.9         1261.7  ...
#
#    Estimated_Domestic_Gold_Price_INR_per_10g  Repo_Rate_Pct  \
# 0                                32040.24503           7.75
# 1                                30282.85372           7.75
# 2                                31099.79676           7.75
# 3                                28094.52563           7.75
# 4                                24513.69167           7.75
#
#    Gold_Imports_Tonnes_Annual  Monthly_Gold_Price_Change_Pct  \
# 0                       974.0                            NaN
# 1                       974.0                            NaN
# 2                       974.0                            NaN
# 3                       974.0                            NaN
# 4                       974.0                            NaN
#
#    Monthly_USD_INR_Change_Pct  YoY_Growth_Pct        MA_3M        MA_6M  \
# 0                         NaN             NaN  32040.24503  32040.24503
# 1                         NaN             NaN  31161.54937  31161.54937
# 2                         NaN             NaN  31140.96517  31140.96517
# 3                         NaN             NaN  30379.35528  30379.35528
# 4                         NaN             NaN  29206.22256  29206.22256
#
#         MA_12M  Rolling_Volatility_30D
# 0  32040.24503                     NaN
# 1  31161.54937                     NaN
# 2  31140.96517                5.446918
# 3  30379.35528                5.851831
# 4  29206.22256                6.426772
#
# [5 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3085 entries, 0 to 3084
# Data columns (total 30 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Date                                       3085 non-null   object
#  1   Year                                       3085 non-null   int64
#  2   Month                                      3085 non-null   int64
#  3   Month_Number                               3085 non-null   int64
#  4   MonthName                                  3085 non-null   object
#  5   Quarter                                    3085 non-null   object
#  6   FinancialYear                              3085 non-null   object
#  7   Gold_Price_USD_per_oz                      3085 non-null   float64
#  8   Gold_Open_USD                              3085 non-null   float64
#  9   Gold_High_USD                              3085 non-null   float64
#  10  Gold_Low_USD                               3085 non-null   float64
#  11  Gold_Daily_Change_Pct                      3085 non-null   float64
#  12  USD_INR_Rate                               3085 non-null   float64
#  13  Gold_Price_INR_per_oz                      3085 non-null   float64
#  14  Gold_Price_INR_per_10g                     3085 non-null   float64
#  15  Import_Duty_Rate_Pct                       3085 non-null   float64
#  16  Import_Duty_Amount_INR_per_10g             3085 non-null   float64
#  17  GST_Rate_Pct                               3085 non-null   int64
#  18  GST_Amount_INR_per_10g                     3085 non-null   float64
#  19  Price_Plus_Duty_INR_per_10g                3085 non-null   float64
#  20  Estimated_Domestic_Gold_Price_INR_per_10g  3085 non-null   float64
#  21  Repo_Rate_Pct                              3085 non-null   float64
#  22  Gold_Imports_Tonnes_Annual                 2743 non-null   float64
#  23  Monthly_Gold_Price_Change_Pct              3064 non-null   float64
#  24  Monthly_USD_INR_Change_Pct                 3064 non-null   float64
#  25  YoY_Growth_Pct                             2839 non-null   float64
#  26  MA_3M                                      3085 non-null   float64
#  27  MA_6M                                      3085 non-null   float64
#  28  MA_12M                                     3085 non-null   float64
#  29  Rolling_Volatility_30D                     3083 non-null   float64
# dtypes: float64(22), int64(4), object(4)
# memory usage: 723.2+ KB

# %%
df.isnull().sum()
# Out:
# Date                                           0
# Year                                           0
# Month                                          0
# Month_Number                                   0
# MonthName                                      0
# Quarter                                        0
# FinancialYear                                  0
# Gold_Price_USD_per_oz                          0
# Gold_Open_USD                                  0
# Gold_High_USD                                  0
# Gold_Low_USD                                   0
# Gold_Daily_Change_Pct                          0
# USD_INR_Rate                                   0
# Gold_Price_INR_per_oz                          0
# Gold_Price_INR_per_10g                         0
# Import_Duty_Rate_Pct                           0
# Import_Duty_Amount_INR_per_10g                 0
# GST_Rate_Pct                                   0
# GST_Amount_INR_per_10g                         0
# Price_Plus_Duty_INR_per_10g                    0
# Estimated_Domestic_Gold_Price_INR_per_10g      0
# Repo_Rate_Pct                                  0
# Gold_Imports_Tonnes_Annual                   342
# Monthly_Gold_Price_Change_Pct                 21
# Monthly_USD_INR_Change_Pct                    21
# YoY_Growth_Pct                               246
# MA_3M                                          0
# MA_6M                                          0
# MA_12M                                         0
# Rolling_Volatility_30D                         2
# dtype: int64

# %%
df = f.fillna(0)

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.dtypes
# Out:
# Date                                         datetime64[ns]
# Year                                                  int64
# Month                                                 int64
# Month_Number                                          int64
# MonthName                                            object
# Quarter                                              object
# FinancialYear                                        object
# Gold_Price_USD_per_oz                               float64
# Gold_Open_USD                                       float64
# Gold_High_USD                                       float64
# Gold_Low_USD                                        float64
# Gold_Daily_Change_Pct                               float64
# USD_INR_Rate                                        float64
# Gold_Price_INR_per_oz                               float64
# Gold_Price_INR_per_10g                              float64
# Import_Duty_Rate_Pct                                float64
# Import_Duty_Amount_INR_per_10g                      float64
# GST_Rate_Pct                                          int64
# GST_Amount_INR_per_10g                              float64
# Price_Plus_Duty_INR_per_10g                         float64
# Estimated_Domestic_Gold_Price_INR_per_10g           float64
# Repo_Rate_Pct                                       float64
# Gold_Imports_Tonnes_Annual                          float64
# Monthly_Gold_Price_Change_Pct                       float64
# Monthly_USD_INR_Change_Pct                          float64
# YoY_Growth_Pct                                      float64
# MA_3M                                               float64
# MA_6M                                               float64
# MA_12M                                              float64
# Rolling_Volatility_30D                              float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (3085, 30)

# %%
df.to_csv("dataset_cleaned(1).csv")

# %% [markdown]
# ## DAY 12
#
# ### EXPLORATORY DATA ANALYSIS (E

# %% [markdown]
# #### SUMMARY STATS

# %%
df[["Gold_Price_USD_per_oz","Gold_Open_USD","Gold_High_USD"]].describe()
# Out:
#        Gold_Price_USD_per_oz  Gold_Open_USD  Gold_High_USD
# count             3085.00000    3085.000000    3085.000000
# mean              1815.46800    1815.554318    1830.195634
# std                866.78761     866.747897     878.933259
# min               1049.60000    1051.500000    1062.700000
# 25%               1268.40000    1268.000000    1276.800000
# 50%               1523.60000    1526.600000    1542.800000
# 75%               1915.40000    1916.700000    1929.400000
# max               5354.80000    5449.900000    5626.800000

# %% [markdown]
# #### DISTRIBUTION

# %%
# GOLD PRICE

import matplotlib.pyplot as plt
plt.figure(figsize=(5,4))
plt.hist(df["Gold_Price_USD_per_oz"], bins=30)
plt.title("Distribution of Gold Price per oz")
plt.xlabel("Gold Price")
plt.ylabel("Frequency")
plt.show()

# %%
# GOLD OPEN
plt.figure(figsize=(6,4))
plt.hist(df["Gold_Open_USD"], bins=30)
plt.title("Distribution of Gold Open Price")
plt.xlabel("Gold Open")
plt.ylabel("Frequency")
plt.show()

# %%
# GOLD HIGJ

plt.figure(figsize=(6,4))
plt.hist(df["Gold_High_USD"], bins=30)
plt.title("Distribution od Gold High Price")
plt.xlabel("Gold High")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# #### SEGMENT BY QUARTER

# %%
df.groupby("Quarter")[ ["Gold_Price_USD_per_oz", "Gold_Open_USD", "Gold_High_USD"]].mean()
# Out:
#          Gold_Price_USD_per_oz  Gold_Open_USD  Gold_High_USD
# Quarter
# Q1                 1913.495082    1913.701454    1931.212086
# Q2                 1903.291967    1903.980799    1919.641650
# Q3                 1726.140182    1726.186411    1738.284395
# Q4                 1709.563501    1708.918589    1722.044030

# %% [markdown]
# #### SEGMENT BY MonthName

# %%
df.groupby("MonthName")["Gold_Price_USD_per_oz"].mean()
# Out:
# MonthName
# April        1933.788846
# August       1699.089883
# December     1694.247436
# February     1942.516138
# January      1895.536479
# July         1776.000375
# June         1880.798092
# March        1905.062590
# May          1895.638609
# November     1694.365702
# October      1737.386590
# September    1700.177959
# Name: Gold_Price_USD_per_oz, dtype: float64

# %% [markdown]
# #### SEGMENT BY FinancialYear

# %%
df.groupby("FinancialYear")["Gold_Price_USD_per_oz"].mean()
# Out:
# FinancialYear
# FY12-13    1545.545763
# FY13-14    1346.630588
# FY14-15    1244.792829
# FY15-16    1163.516000
# FY16-17    1255.792430
# FY17-18    1277.199010
# FY18-19    1278.080905
# FY19-20    1488.828704
# FY20-21    1813.483465
# FY21-22    1813.780392
# FY22-23    1819.252217
# FY23-24    2013.458081
# FY24-25    2625.750251
# FY25-26    3953.991689
# FY26-27    4515.343243
# Name: Gold_Price_USD_per_oz, dtype: float64

# %% [markdown]
# #### DAY AND DAY_NAME FROM YEAR

# %%
df["Derived_Day"] = df["Date"].dt.day

# %%
df["Derived_DayName"] = df["Date"].dt.day_name()

# %%
df[[
    "Derived_Day",
    "Derived_DayName"
]].head()
# Out:
#    Derived_Day Derived_DayName
# 0            2       Wednesday
# 1            3        Thursday
# 2            4          Friday
# 3            5        Saturday
# 4            7          Monday

# %% [markdown]
# ## DAY 13

# %% [markdown]
# ### OUTLIER ANALYSIS

# %%
# Gold Price per oz

Q1 = df["Gold_Price_USD_per_oz"].quantile(0.25)
Q3 = df["Gold_Price_USD_per_oz"].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
outliers = df[(df["Gold_Price_USD_per_oz"] < lower) |
              (df["Gold_Price_USD_per_oz"] > upper)]
print(len(outliers))
# Out:
# 323

# %%
# Gold Price Open

Q1 = df["Gold_Open_USD"].quantile(0.25)
Q3 = df["Gold_Open_USD"].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
outliers = df[(df["Gold_Open_USD"] < lower) |
              (df["Gold_Open_USD"] > upper)]
print(len(outliers))
# Out:
# 320

# %%
# Gold Price High

Q1 = df["Gold_High_USD"].quantile(0.25)
Q3 = df["Gold_High_USD"].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR
outliers = df[(df["Gold_High_USD"] < lower) |
              (df["Gold_High_USD"] > upper)]
print(len(outliers))
# Out:
# 321

# %% [markdown]
# ### CHARTS

# %%
plt.figure(figsize=(10,5))
plt.plot(df["Date"], df["Gold_Price_INR_per_10g"])
plt.title("Gold Price Trend Over the Years")
plt.xlabel("Date")
plt.ylabel("Gold Price")
plt.show()

# %%
quarter = df["Quarter"].value_counts()
plt.pie(quarter,labels=quarter.index,autopct="%1.1f%%")
plt.title("Records by Quarter")
plt.show()

# %%
plt.hist(df["Gold_Price_INR_per_10g"], bins=20 , color = "skyblue")
plt.title("Distribution of Gold Price")
plt.xlabel("Gold Price Grams")
plt.ylabel("Frequency")
plt.show()

# %%
quarter = df.groupby("Quarter")["Gold_Price_INR_per_10g"].mean()
plt.bar(quarter.index, quarter.values , color ="pink")
plt.title("Average Gold Price by Quarter")
plt.xlabel("Quarters")
plt.ylabel("Average Price")
plt.show()

# %%
imports = df.groupby("Year")["Gold_Imports_Tonnes_Annual"].mean()
plt.bar(imports.index, imports.values, color="yellow")
plt.title("Gold Imports by Year")
plt.xlabel("Year")
plt.ylabel("Gold Imports in Tones")
plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10,5))
ax1.plot(df["Date"], df["Gold_Price_INR_per_10g"])
ax1.set_ylabel("Gold Price (INR per 10g)")
ax1.set_xlabel("Date")
ax2 = ax1.twinx()
ax2.plot(df["Date"], df["USD_INR_Rate"])
ax2.set_ylabel("USD-INR Rate")
plt.title("Gold Price vs USD-INR Exchange Rate")
plt.show()

# %% [markdown]
# #### Gold Price has Significantly Increased Over the Years(2013-26)
# #### We can see that there is a sudden increase in gold prices after from 2024

# %% [markdown]
# ## DAY 14

# %% [markdown]
# #### DESCRIPTIVE STATS

# %%
df[["Gold_Price_USD_per_oz", "Gold_Open_USD", "Gold_High_USD"]].describe()
# Out:
#        Gold_Price_USD_per_oz  Gold_Open_USD  Gold_High_USD
# count             3085.00000    3085.000000    3085.000000
# mean              1815.46800    1815.554318    1830.195634
# std                866.78761     866.747897     878.933259
# min               1049.60000    1051.500000    1062.700000
# 25%               1268.40000    1268.000000    1276.800000
# 50%               1523.60000    1526.600000    1542.800000
# 75%               1915.40000    1916.700000    1929.400000
# max               5354.80000    5449.900000    5626.800000

# %% [markdown]
# #### DISTRIBUTION ANALYSIS - Already performed above

# %% [markdown]
# #### SKEWNESS

# %%
print(df["Gold_Price_USD_per_oz"].skew())
# Out:
# 2.1469486018073174

# %%
print(df["Gold_Open_USD"].skew())
# Out:
# 2.151519682669083

# %%
print(df["Gold_High_USD"].skew())
# Out:
# 2.1665867066165676

# %% [markdown]
# #### KURTOSIS

# %%
print(df["Gold_Price_USD_per_oz"].kurt())
# Out:
# 4.224652127755245

# %%
print(df["Gold_Open_USD"].kurt())
# Out:
# 4.258958875505064

# %%
print(df["Gold_High_USD"].kurt())
# Out:
# 4.3356393690106545

# %%
----- DOCUMENTING IS PENDING-----

# %% [markdown]
# ## DAY 15
